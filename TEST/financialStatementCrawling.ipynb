# %%
import OpenDartReader
import pandas as pd
import numpy as np

api_key = '7e0ed3ef8b1336aacf1a28b13374d77072afdaa6'

dart = OpenDartReader(api_key)

# dart.list('삼성전자', start='2015-01-01', end='2025-03-31', kind='A')
dart.finstate('005930', 2024)
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 1   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 2   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 3   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 4   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 5   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 6   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 7   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 8   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 9   20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# 10  20250311001085      11011      2024  00126380     005930    CFS  연결재무제표
# ...
