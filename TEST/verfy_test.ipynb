# %%
import sys

sys.path.append(r'C:/PythonProjects/ljt1105/TradeVerification/modules')

import read_files
import refine_data
import reconcile_data

import numpy as np
import pandas as pd
from tabulate import tabulate
import datetime
import time

# %%
oms_df, trader_df, td, td_tr = read_files.read_df_files()
time.sleep(1)
trader_df3, oms_df4 = refine_data.refine_df(oms_df, trader_df, td)
time.sleep(1)
difference_df = reconcile_data.reconcile_data(trader_df3, oms_df4, td)
# Out:
# Today : 20230609
# File load completed
# C:/PythonProjects/ljt1105/TradeVerification/modules\refine_data.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oms_df1["매매구분"] = oms_df1[["매매유형", "매매구분"]].agg('_'.join, axis=1)
# C:/PythonProjects/ljt1105/TradeVerification/modules\refine_data.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oms_df1["매매구분"] = oms_df1["매매구분"].replace(['일반_매수', '일반_매도', '차입_매수', '차입_매도'], ['Buy', 'Sell', 'Buy cover', 'Short sell'])
# Refining comlpeted
# Calculating comlpeted. Showing result
# +-------------------------------------------------+-------------+-------------+-------------+--------------+--------------+--------------+---------------+---------------+---------------+
# |                                                 | 체결수량_td | 체결단가_td | 체결금액_td | 체결수량_oms | 체결단가_oms | 체결금액_oms | 체결수량_차이 | 체결단가_차이 | 체결금액_차이 |
# +-------------------------------------------------+-------------+-------------+-------------+--------------+--------------+--------------+---------------+---------------+---------------+
# |        ('공모주1호', '기가비스', 'Buy')         |    100.0    |   69447.0   |  6944700.0  |    100.0     |   69447.0    |  6944700.0   |      0.0      |      0.0      |      0.0      |
# |       ('공모주1호', '기아', 'Buy cover')        |    634.0    |   81611.0   | 51741374.0  |    634.0     |   81611.0    |  51741400.0  |      0.0      |      0.0      |     -26.0     |
# |   ('공모주1호', '대주전자재료', 'Short sell')   |    100.0    |   97647.0   |  9764700.0  |    100.0     |   97647.0    |  9764700.0   |      0.0      |      0.0      |      0.0      |
# |        ('공모주1호', '삼성SDI', 'Sell')         |    30.0     |  720667.0   | 21620010.0  |     30.0     |   720667.0   |  21620000.0  |      0.0      |      0.0      |     10.0      |
# |         ('공모주1호', '제이오', 'Sell')         |    200.0    |   32498.0   |  6499600.0  |    200.0     |   32498.0    |  6499500.0   |      0.0      |      0.0      |     100.0     |
# |    ('공모주1호', '코스닥150F', 'Buy cover')     |     7.0     |   1346.0    |   9423.0    |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |    ('공모주1호', '코스닥150F', 'Short sell')    |     7.0     |   1338.0    |   9372.0    |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |    ('공모주1호', '코스피200F', 'Buy cover')     |     2.0     |    342.0    |    684.0    |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |    ('공모주1호', '코스피200F', 'Short sell')    |     2.0     |    344.0    |    688.0    |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# | ('멀티전략', 'KODEX코스닥150선물인버스', 'Buy') |   10000.0   |   3984.0    | 39840000.0  |   10000.0    |    3984.0    |  39838000.0  |      0.0      |      0.0      |    2000.0     |
# |      ('멀티전략', 'LG전자', 'Short sell')       |    20.0     |  126200.0   |  2524000.0  |     20.0     |   126200.0   |  2524000.0   |      0.0      |      0.0      |      0.0      |
# |    ('멀티전략', 'POSCO홀딩스', 'Short sell')    |    30.0     |  388417.0   | 11652510.0  |     30.0     |   388417.0   |  11652500.0  |      0.0      |      0.0      |     10.0      |
# |     ('멀티전략', 'SFA반도체', 'Short sell')     |   1034.0    |   5869.0    |  6068546.0  |    1034.0    |    5869.0    |  6068580.0   |      0.0      |      0.0      |     -34.0     |
# |         ('멀티전략', '기가비스', 'Buy')         |    100.0    |   69466.0   |  6946600.0  |    100.0     |   69466.0    |  6946600.0   |      0.0      |      0.0      |      0.0      |
# |        ('멀티전략', '기아', 'Buy cover')        |    632.0    |   81613.0   | 51579416.0  |    632.0     |   81613.0    |  51579300.0  |      0.0      |      0.0      |     116.0     |
# |       ('멀티전략', '넥스틴', 'Buy cover')       |    500.0    |   73994.0   | 37008300.0  |    500.0     |   73994.0    |  37008300.0  |      0.0      |      0.0      |      0.0      |
# |  ('멀티전략', '레이크머티리얼즈', 'Buy cover')  |   1700.0    |   14729.0   | 25039300.0  |    1700.0    |   14729.0    |  25038940.0  |      0.0      |      0.0      |     360.0     |
# |         ('멀티전략', '메디톡스', 'Buy')         |    108.0    |  266458.0   | 28777464.0  |    108.0     |   266458.0   |  28777500.0  |      0.0      |      0.0      |     -36.0     |
# |         ('멀티전략', '삼성전기', 'Buy')         |    70.0     |  145107.0   | 10157490.0  |     70.0     |   145107.0   |  10157500.0  |      0.0      |      0.0      |     -10.0     |
# |         ('멀티전략', '삼성전자', 'Buy')         |    200.0    |   70602.0   | 14120500.0  |    200.0     |   70602.0    |  14120500.0  |      0.0      |      0.0      |      0.0      |
# |      ('멀티전략', '원익IPS', 'Short sell')      |    200.0    |   31269.0   |  6253800.0  |    200.0     |   31269.0    |  6253850.0   |      0.0      |      0.0      |     -50.0     |
# |     ('멀티전략', '코스닥150F', 'Buy cover')     |    35.0     |   1345.0    |   47103.0   |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |    ('멀티전략', '코스닥150F', 'Short sell')     |    35.0     |   1338.0    |   46847.0   |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |     ('멀티전략', '코스피200F', 'Buy cover')     |     1.0     |    342.0    |    342.0    |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |    ('멀티전략', '코스피200F', 'Short sell')     |     1.0     |    343.0    |    343.0    |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |       ('멀티전략', '테스', 'Short sell')        |    500.0    |   21246.0   | 10623000.0  |    500.0     |   21246.0    |  10622900.0  |      0.0      |      0.0      |     100.0     |
# |   ('멀티전략', '하나마이크론', 'Short sell')    |   1362.0    |   18108.0   | 24423670.0  |    1362.0    |   18108.0    |  24423900.0  |      0.0      |      0.0      |    -230.0     |
# |        ('멀티전략', '한온시스템', 'Buy')        |   1000.0    |   9273.0    |  9273000.0  |    1000.0    |    9273.0    |  9272510.0   |      0.0      |      0.0      |     490.0     |
# |         ('코스닥벤처', 'HPSP', 'Sell')          |    800.0    |   26964.0   | 21571200.0  |    800.0     |   26964.0    |  21570850.0  |      0.0      |      0.0      |     350.0     |
# |  ('코스닥벤처', 'KODEX200선물인버스', 'Sell')   |   40000.0   |   2492.0    | 99680000.0  |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |    ('코스닥벤처', 'LG이노텍', 'Short sell')     |    49.0     |  301500.0   | 14773500.0  |     49.0     |   301500.0   |  14773500.0  |      0.0      |      0.0      |      0.0      |
# |   ('코스닥벤처', 'POSCO홀딩스', 'Short sell')   |    60.0     |  388458.0   | 23307480.0  |     60.0     |   388458.0   |  23307500.0  |      0.0      |      0.0      |     -20.0     |
# |    ('코스닥벤처', 'SFA반도체', 'Short sell')    |   1010.0    |   5870.0    |  5928700.0  |    1010.0    |    5870.0    |  5928990.0   |      0.0      |      0.0      |    -290.0     |
# |        ('코스닥벤처', '기가비스', 'Buy')        |    100.0    |   69470.0   |  6947000.0  |    100.0     |   69470.0    |  6947000.0   |      0.0      |      0.0      |      0.0      |
# |       ('코스닥벤처', '기아', 'Buy cover')       |    779.0    |   81627.0   | 63587433.0  |    779.0     |   81627.0    |  63587200.0  |      0.0      |      0.0      |     233.0     |
# |     ('코스닥벤처', '넥스틴', 'Short sell')      |    183.0    |   72923.0   | 13344909.0  |    183.0     |   72923.0    |  13345000.0  |      0.0      |      0.0      |     -91.0     |
# |  ('코스닥벤처', '대주전자재료', 'Short sell')   |    200.0    |   97665.0   | 19533000.0  |    200.0     |   97665.0    |  19532900.0  |      0.0      |      0.0      |     100.0     |
# |       ('코스닥벤처', '더블유씨피', 'Buy')       |    200.0    |   53718.0   | 10743600.0  |    200.0     |   53718.0    |  10743500.0  |      0.0      |      0.0      |     100.0     |
# |        ('코스닥벤처', '메디톡스', 'Buy')        |    223.0    |  266805.0   | 59497515.0  |    223.0     |   266805.0   |  59497500.0  |      0.0      |      0.0      |     15.0      |
# |     ('코스닥벤처', '원익IPS', 'Short sell')     |    800.0    |   31481.0   | 25184800.0  |    800.0     |   31481.0    |  25184950.0  |      0.0      |      0.0      |    -150.0     |
# |   ('코스닥벤처', '유안타제10호스팩', 'Sell')    |    654.0    |   2148.0    |  1404792.0  |    654.0     |    2148.0    |  1404960.0   |      0.0      |      0.0      |    -168.0     |
# |    ('코스닥벤처', '코스닥150F', 'Buy cover')    |    86.0     |   1346.0    |  115790.0   |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |   ('코스닥벤처', '코스닥150F', 'Short sell')    |    86.0     |   1339.0    |  115157.0   |     nan      |     nan      |     nan      |      nan      |      nan      |      nan      |
# |       ('코스닥벤처', '퓨런티어', 'Sell')        |    200.0    |   29503.0   |  5900600.0  |    200.0     |   29503.0    |  5900650.0   |      0.0      |      0.0      |     -50.0     |
# |  ('코스닥벤처', '하나마이크론', 'Short sell')   |   1550.0    |   17447.0   | 27085600.0  |    1550.0    |   17447.0    |  27085690.0  |      0.0      |      0.0      |     -90.0     |
# |    ('코스닥벤처', '하이비젼시스템', 'Sell')     |    500.0    |   20923.0   | 10461500.0  |    500.0     |   20923.0    |  10461600.0  |      0.0      |      0.0      |    -100.0     |
# | ('코스닥벤처', 'KODEX200선물인버스2X', 'Sell')  |     nan     |     nan     |     nan     |   40000.0    |    2492.0    |  99689305.0  |      nan      |      nan      |      nan      |
# +-------------------------------------------------+-------------+-------------+-------------+--------------+--------------+--------------+---------------+---------------+---------------+

# %%
difference_df
# Out:
#                                    체결수량_td   체결단가_td     체결금액_td  체결수량_oms  \
# 펀드    종목명              매매구분
# 공모주1호 기가비스             Buy           100.0   69447.0   6944700.0     100.0
#       기아               Buy cover     634.0   81611.0  51741374.0     634.0
#       대주전자재료           Short sell    100.0   97647.0   9764700.0     100.0
#       삼성SDI            Sell           30.0  720667.0  21620010.0      30.0
#       제이오              Sell          200.0   32498.0   6499600.0     200.0
#       코스닥150F          Buy cover       7.0    1346.0      9423.0       NaN
#                        Short sell      7.0    1338.0      9372.0       NaN
#       코스피200F          Buy cover       2.0     342.0       684.0       NaN
#                        Short sell      2.0     344.0       688.0       NaN
# 멀티전략  KODEX코스닥150선물인버스 Buy         10000.0    3984.0  39840000.0   10000.0
#       LG전자             Short sell     20.0  126200.0   2524000.0      20.0
#       POSCO홀딩스         Short sell     30.0  388417.0  11652510.0      30.0
#       SFA반도체           Short sell   1034.0    5869.0   6068546.0    1034.0
#       기가비스             Buy           100.0   69466.0   6946600.0     100.0
#       기아               Buy cover     632.0   81613.0  51579416.0     632.0
#       넥스틴              Buy cover     500.0   73994.0  37008300.0     500.0
#       레이크머티리얼즈         Buy cover    1700.0   14729.0  25039300.0    1700.0
#       메디톡스             Buy           108.0  266458.0  28777464.0     108.0
#       삼성전기             Buy            70.0  145107.0  10157490.0      70.0
#       삼성전자             Buy           200.0   70602.0  14120500.0     200.0
#       원익IPS            Short sell    200.0   31269.0   6253800.0     200.0
#       코스닥150F          Buy cover      35.0    1345.0     47103.0       NaN
#                        Short sell     35.0    1338.0     46847.0       NaN
#       코스피200F          Buy cover       1.0     342.0       342.0       NaN
#                        Short sell      1.0     343.0       343.0       NaN
#       테스               Short sell    500.0   21246.0  10623000.0     500.0
#       하나마이크론           Short sell   1362.0   18108.0  24423670.0    1362.0
#       한온시스템            Buy          1000.0    9273.0   9273000.0    1000.0
# 코스닥벤처 HPSP             Sell          800.0   26964.0  21571200.0     800.0
#       KODEX200선물인버스    Sell        40000.0    2492.0  99680000.0       NaN
#       LG이노텍            Short sell     49.0  301500.0  14773500.0      49.0
#       POSCO홀딩스         Short sell     60.0  388458.0  23307480.0      60.0
#       SFA반도체           Short sell   1010.0    5870.0   5928700.0    1010.0
#       기가비스             Buy           100.0   69470.0   6947000.0     100.0
#       기아               Buy cover     779.0   81627.0  63587433.0     779.0
#       넥스틴              Short sell    183.0   72923.0  13344909.0     183.0
#       대주전자재료           Short sell    200.0   97665.0  19533000.0     200.0
#       더블유씨피            Buy           200.0   53718.0  10743600.0     200.0
#       메디톡스             Buy           223.0  266805.0  59497515.0     223.0
#       원익IPS            Short sell    800.0   31481.0  25184800.0     800.0
#       유안타제10호스팩        Sell          654.0    2148.0   1404792.0     654.0
#       코스닥150F          Buy cover      86.0    1346.0    115790.0       NaN
#                        Short sell     86.0    1339.0    115157.0       NaN
#       퓨런티어             Sell          200.0   29503.0   5900600.0     200.0
#       하나마이크론           Short sell   1550.0   17447.0  27085600.0    1550.0
#       하이비젼시스템          Sell          500.0   20923.0  10461500.0     500.0
#       KODEX200선물인버스2X  Sell            NaN       NaN         NaN   40000.0
#
#                                    체결단가_oms    체결금액_oms  체결수량_차이  체결단가_차이  \
# 펀드    종목명              매매구분
# 공모주1호 기가비스             Buy          69447.0   6944700.0      0.0      0.0
#       기아               Buy cover    81611.0  51741400.0      0.0      0.0
#       대주전자재료           Short sell   97647.0   9764700.0      0.0      0.0
#       삼성SDI            Sell        720667.0  21620000.0      0.0      0.0
#       제이오              Sell         32498.0   6499500.0      0.0      0.0
#       코스닥150F          Buy cover        NaN         NaN      NaN      NaN
#                        Short sell       NaN         NaN      NaN      NaN
#       코스피200F          Buy cover        NaN         NaN      NaN      NaN
#                        Short sell       NaN         NaN      NaN      NaN
# 멀티전략  KODEX코스닥150선물인버스 Buy           3984.0  39838000.0      0.0      0.0
#       LG전자             Short sell  126200.0   2524000.0      0.0      0.0
#       POSCO홀딩스         Short sell  388417.0  11652500.0      0.0      0.0
#       SFA반도체           Short sell    5869.0   6068580.0      0.0      0.0
#       기가비스             Buy          69466.0   6946600.0      0.0      0.0
#       기아               Buy cover    81613.0  51579300.0      0.0      0.0
#       넥스틴              Buy cover    73994.0  37008300.0      0.0      0.0
#       레이크머티리얼즈         Buy cover    14729.0  25038940.0      0.0      0.0
#       메디톡스             Buy         266458.0  28777500.0      0.0      0.0
#       삼성전기             Buy         145107.0  10157500.0      0.0      0.0
#       삼성전자             Buy          70602.0  14120500.0      0.0      0.0
#       원익IPS            Short sell   31269.0   6253850.0      0.0      0.0
#       코스닥150F          Buy cover        NaN         NaN      NaN      NaN
#                        Short sell       NaN         NaN      NaN      NaN
#       코스피200F          Buy cover        NaN         NaN      NaN      NaN
#                        Short sell       NaN         NaN      NaN      NaN
#       테스               Short sell   21246.0  10622900.0      0.0      0.0
#       하나마이크론           Short sell   18108.0  24423900.0      0.0      0.0
#       한온시스템            Buy           9273.0   9272510.0      0.0      0.0
# 코스닥벤처 HPSP             Sell         26964.0  21570850.0      0.0      0.0
#       KODEX200선물인버스    Sell             NaN         NaN      NaN      NaN
#       LG이노텍            Short sell  301500.0  14773500.0      0.0      0.0
#       POSCO홀딩스         Short sell  388458.0  23307500.0      0.0      0.0
#       SFA반도체           Short sell    5870.0   5928990.0      0.0      0.0
#       기가비스             Buy          69470.0   6947000.0      0.0      0.0
#       기아               Buy cover    81627.0  63587200.0      0.0      0.0
#       넥스틴              Short sell   72923.0  13345000.0      0.0      0.0
#       대주전자재료           Short sell   97665.0  19532900.0      0.0      0.0
#       더블유씨피            Buy          53718.0  10743500.0      0.0      0.0
#       메디톡스             Buy         266805.0  59497500.0      0.0      0.0
#       원익IPS            Short sell   31481.0  25184950.0      0.0      0.0
#       유안타제10호스팩        Sell          2148.0   1404960.0      0.0      0.0
#       코스닥150F          Buy cover        NaN         NaN      NaN      NaN
#                        Short sell       NaN         NaN      NaN      NaN
#       퓨런티어             Sell         29503.0   5900650.0      0.0      0.0
#       하나마이크론           Short sell   17447.0  27085690.0      0.0      0.0
#       하이비젼시스템          Sell         20923.0  10461600.0      0.0      0.0
#       KODEX200선물인버스2X  Sell          2492.0  99689305.0      NaN      NaN
#
#                                    체결금액_차이
# 펀드    종목명              매매구분
# 공모주1호 기가비스             Buy             0.0
#       기아               Buy cover     -26.0
#       대주전자재료           Short sell      0.0
#       삼성SDI            Sell           10.0
#       제이오              Sell          100.0
#       코스닥150F          Buy cover       NaN
#                        Short sell      NaN
#       코스피200F          Buy cover       NaN
#                        Short sell      NaN
# 멀티전략  KODEX코스닥150선물인버스 Buy          2000.0
#       LG전자             Short sell      0.0
#       POSCO홀딩스         Short sell     10.0
#       SFA반도체           Short sell    -34.0
#       기가비스             Buy             0.0
#       기아               Buy cover     116.0
#       넥스틴              Buy cover       0.0
#       레이크머티리얼즈         Buy cover     360.0
#       메디톡스             Buy           -36.0
#       삼성전기             Buy           -10.0
#       삼성전자             Buy             0.0
#       원익IPS            Short sell    -50.0
#       코스닥150F          Buy cover       NaN
#                        Short sell      NaN
#       코스피200F          Buy cover       NaN
#                        Short sell      NaN
#       테스               Short sell    100.0
#       하나마이크론           Short sell   -230.0
#       한온시스템            Buy           490.0
# 코스닥벤처 HPSP             Sell          350.0
#       KODEX200선물인버스    Sell            NaN
#       LG이노텍            Short sell      0.0
#       POSCO홀딩스         Short sell    -20.0
#       SFA반도체           Short sell   -290.0
#       기가비스             Buy             0.0
#       기아               Buy cover     233.0
#       넥스틴              Short sell    -91.0
#       대주전자재료           Short sell    100.0
#       더블유씨피            Buy           100.0
#       메디톡스             Buy            15.0
#       원익IPS            Short sell   -150.0
#       유안타제10호스팩        Sell         -168.0
#       코스닥150F          Buy cover       NaN
#                        Short sell      NaN
#       퓨런티어             Sell          -50.0
#       하나마이크론           Short sell    -90.0
#       하이비젼시스템          Sell         -100.0
#       KODEX200선물인버스2X  Sell            NaN
