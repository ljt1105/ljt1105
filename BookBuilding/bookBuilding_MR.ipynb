# %%
import time
from selenium import webdriver as wd
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

def ipo_go_in(wait):
    driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="contentframe"]'))
    wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="gnb"]/li[8]/a'))).click()

    driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="popIframe"]'))
    wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="menu01"]/dd[2]/ul/li[4]/a[2]'))).click()
    wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="0000000482_3"]/li[10]/a[2]'))).click()
    wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="0000000490_9"]/li[2]/a'))).click()
    
    # 수요예측 페이지 URL: https://securities.miraeasset.com/hku/hku4051/c01.do
    # driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="contentframe"]'))
    # 사업자등록번호: //*[@id="businessno"]
    # business_number = wait.until(driver.find_element(by=By.XPATH, value='//*[@id="businessno"]'))
    # wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="businessno"]'))).click()
    # business_number = wait.until(EC.visibility_of_element_located((By.XPATH, '//*[@id="businessno"]')))
    time.sleep(2)
    business_number = driver.find_element(By.XPATH, "//*[@id='businessno']")
    # business_number.clear()
    business_number.send_keys(2278700979)


MR_path = 'https://securities.miraeasset.com/'
options = wd.ChromeOptions()
driver = wd.Chrome()
driver.maximize_window()
driver.get(MR_path)
wait = WebDriverWait(driver, 10)

if __name__ == "__main__":
    ipo_go_in(wait)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In [12], line 36
#      33 wait = WebDriverWait(driver, 10)
#      35 if __name__ == "__main__":
# ---> 36     ipo_go_in(wait)
#
# Cell In [12], line 23, in ipo_go_in(wait)
#      16 # 수요예측 페이지 URL: https://securities.miraeasset.com/hku/hku4051/c01.do
#      17 # driver.switch_to.frame(driver.find_element(By.XPATH, '//*[@id="contentframe"]'))
#      18 # 사업자등록번호: //*[@id="businessno"]
#      19 # business_number = wait.until(driver.find_element(by=By.XPATH, value='//*[@id="businessno"]'))
#      20 # wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="businessno"]'))).click()
#      21 # business_number = wait.until(EC.visibility_of_element_located((By.XPATH, '//*[@id="businessno"]')))
#      22 time.sleep(2)
# ---> 23 business_number = driver.find_element(By.XPATH, "//*[@id='businessno']")
# ...

# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup

s = HTMLSession()
url = 'https://securities.miraeasset.com/hku/hku4051/c01.do'


def getdata(url):
    r = s.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup


# for i in range(1, 103):


def getnextpage(soup):
    page = soup.find_all()
    return page


soup = getdata(url)
print(getnextpage(soup))
# Out:
# [<html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="no-store" http-equiv="cache-control"/>
# <link href="https://img.securities.miraeasset.com/new2016/layout/favicon.ico" rel="shortcut icon"/>
# <script type="text/javascript">
#
#
# 	//Mobile web mapping url and replcae url array
# 	var urlArray = [
# 	                "/hku/hku3005/u01.do",
# 	                "/hku/hku2001/c07.do",
# 	                "/hku/hku2001/t01.do",
# 	                "/bbs/board/message/list.do?categoryId=1296",
# 	                "/hkd/hkd1001/r01.do",
# 	                "/hkp/hkp1002/r01.do",
# 	                "/hkp/hkp2001/r01.do",
# 	                "/hkd/hkd1005/r01.do",
# 	                "/hks/hks4116/r01.do",
# ...
