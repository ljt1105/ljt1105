# %% [markdown]
# 1. 시작
#  - yb_position.xlsx를 통해서 기초 주식 포지션에 대한 (펀드, 종목명, 수량, 진입평균단가, YB 당일 단가, 평가손익, 매니저) 기초 정보 인식
#  - 모든 종목들에 대한 평가손익은 기초에 0으로 인식되어야 함. 쓰여져 있는 평가손익은 남아있어야 할까? 결산때마다 0으로 초기화되니까 필요없다.

# %%
import os
import pandas as pd

# xlsx 파일들이 들어있는 디렉토리 경로
directory_path = "Z:/02.펀드/018. 성과측정/2023/2023TEST"

# 파일 경로
file_path = os.path.join(directory_path, "yb_position.xlsx")

# 엑셀 파일을 데이터프레임으로 읽어들이기
beginning_df = pd.read_excel(file_path)

# %%
beginning_df
# Out:
#       No         일자     펀드코드                                 펀드명  \
# 0      1 2023-06-30  DM11001             두나미스 하이일드 일반사모투자신탁 채권혼합
# 1      2 2023-06-30  DM11001             두나미스 하이일드 일반사모투자신탁 채권혼합
# 2      3 2023-06-30  DM11001             두나미스 하이일드 일반사모투자신탁 채권혼합
# 3      4 2023-06-30  DM11001             두나미스 하이일드 일반사모투자신탁 채권혼합
# 4      5 2023-06-30  DM11001             두나미스 하이일드 일반사모투자신탁 채권혼합
# ..   ...        ...      ...                                 ...
# 220  221 2023-06-30  DM15002  DUNAMIS INVESTMENT HOLDING LIMITED
# 221  222 2023-06-30  DM15002  DUNAMIS INVESTMENT HOLDING LIMITED
# 222  223 2023-06-30  DM15002  DUNAMIS INVESTMENT HOLDING LIMITED
# 223  224 2023-06-30  DM15002  DUNAMIS INVESTMENT HOLDING LIMITED
# 224  225 2023-06-30  DM15002  DUNAMIS INVESTMENT HOLDING LIMITED
#
#              종목코드    단축코드   포지션           종목명       순자산총액     비중  ...  \
# 0    KRQ456490008  456490  LONG  교보14호스팩공모(보)  5855675400   0.04  ...
# ...

# %%
df = beginning_df
